# %%
# 📘 Multimedia Forensics Workbook: Full Code + Explanation

# ✅ Install Required Libraries for Colab (Optional)
# Uncomment the following lines in Colab or Jupyter if packages are missing:
# !pip install grad-cam torch-geometric torch-scatter torch-sparse -f https://data.pyg.org/whl/torch-2.0.0+cpu.html

# ✅ Module 1: CNN - Feature Extraction
# ... (code omitted for brevity - this would contain full CNN, Grad-CAM, GCN, TimeSformer, FGSM logic)
